# %%
#Paso 1 carga de las librerias necesarias

import numpy as np
import pandas as pd

# VISUALIZACION DE DATOS
import matplotlib.pyplot as plt
import seaborn as sns

# ESTADISTICAS
from statsmodels.graphics.gofplots import qqplot
# Esta funcion compara la distribucion de la muestra con una distribucion normal, 
# para comprobar si tu muestra se distribuye normalmente o no.

# %%
# Cargar los datos en un dataframe
Internet_Penetracion = pd.read_csv(r'C:\Users\oomph\Documents\Henry Data Science\DTS09_Proyecto_Individual02\Proyecto-TelecomArg\Internet_Penetracion.csv', sep = ',')
Internet_Penetracion.head()
# Out:
#     Año  Trimestre        Provincia Accesos por cada 100 hogares
# 0  2022          3     Buenos Aires                        78,11
# 1  2022          3  Capital Federal                       122,28
# 2  2022          3        Catamarca                        65,33
# 3  2022          3            Chaco                        43,86
# 4  2022          3           Chubut                        84,38

# %%
# Cargar los datos en un dataframe
Internet_TecyLocalidad = pd.read_csv(r'C:\Users\oomph\Documents\Henry Data Science\DTS09_Proyecto_Individual02\Proyecto-TelecomArg\AccesosaInternetfijoportecnologiaylocalidad_2791751681941036387.csv', sep = ',')
Internet_TecyLocalidad.head()
# Out:
#       Provincia     Partido               Localidad Link Indec ADSL  \
# 0  BUENOS AIRES  25 de Mayo              25 de Mayo    6854100  873
# 1  BUENOS AIRES  25 de Mayo               Del Valle    6854020  181
# 2  BUENOS AIRES  25 de Mayo       Gobernador Ugarte    6854040  - 0
# 3  BUENOS AIRES  25 de Mayo  Norberto de la Riestra    6854060  - 0
# 4  BUENOS AIRES  25 de Mayo        Lucas Monteverde    6854050  - 0
#
#   CABLEMODEM DIAL UP FIBRA OPTICA OTROS SATELITAL WIMAX WIRELESS  \
# 0      4.704     - 0            2   - 0       975   - 0      664
# 1        - 0     - 0          - 0    10         1   - 0      - 0
# 2        - 0     - 0          - 0   - 0       - 0   - 0      181
# 3        782     - 0            6   167       - 0   - 0      327
# 4        - 0     - 0          - 0   - 0       - 0   - 0        6
#
#   Total general  Unnamed: 13
# 0         7.218          NaN
# 1           192          NaN
# 2           181          NaN
# 3         1.282          NaN
# 4             6          NaN

# %%
# Cargar los datos en un dataframe
Velocidad_ProvTrimestral = pd.read_csv(r'C:\Users\oomph\Documents\Henry Data Science\DTS09_Proyecto_Individual02\Proyecto-TelecomArg\historico_velocidad_internet.csv', sep = ',')
Velocidad_ProvTrimestral.head()
# Out:
#     Año  Trimestre Mbps (Media de bajada)    Trimestre.1
# 0  2022          3                  62,46  Jul-Sept 2022
# 1  2022          2                  58,44   Abr-Jun 2022
# 2  2022          1                  55,11   Ene-Mar 2022
# 3  2021          4                  52,34   Oct-Dic 2021
# 4  2021          3                  48,46  Jul-Sept 2021

# %%
Internet_Penetracion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Año                           840 non-null    int64
#  1   Trimestre                     840 non-null    int64
#  2   Provincia                     840 non-null    object
#  3   Accesos por cada 100 hogares  840 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 26.4+ KB

# %%
Internet_TecyLocalidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Provincia      3142 non-null   object
#  1   Partido        3142 non-null   object
#  2   Localidad      3142 non-null   object
#  3   Link Indec     3142 non-null   object
#  4   ADSL           3142 non-null   object
#  5   CABLEMODEM     3142 non-null   object
#  6   DIAL UP        3142 non-null   object
#  7   FIBRA OPTICA   3142 non-null   object
#  8   OTROS          3142 non-null   object
#  9   SATELITAL      3142 non-null   object
#  10  WIMAX          3142 non-null   object
#  11  WIRELESS       3142 non-null   object
#  12  Total general  3142 non-null   object
#  13  Unnamed: 13    0 non-null      float64
# dtypes: float64(1), object(13)
# memory usage: 343.8+ KB

# %%
Velocidad_ProvTrimestral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     35 non-null     int64
#  1   Trimestre               35 non-null     int64
#  2   Mbps (Media de bajada)  35 non-null     object
#  3   Trimestre.1             35 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.2+ KB

# %%
# Verificación de datos faltantes
print(Internet_Penetracion.isnull().sum())
print(accesos_tecnologia_localidad.isnull().sum())

# Estadísticas descriptivas de las variables
print(Internet_Penetracion.describe())
print(accesos_tecnologia_localidad.describe())

# Identificación de valores atípicos
plt.hist(Internet_Penetracion["Accesos por cada 100 hogares"])
plt.show()

# Correlaciones entre variables
correlation_matrix = acceso_tecnologia_localidad.corr()
print(correlation_matrix)

# Visualización de los datos
plt.bar(Internet_Penetracion['Provincia'], Internet_Penetracion['Accesos por cada 100 hogares'])
plt.show()

# Evaluación de la calidad de los datos
data_quality = pd.DataFrame(Internet_Penetracion.dtypes, columns=['Data Type'])
data_quality['Missing Values'] = Internet_Penetracion.isnull().sum()
print(data_quality)

# %%
# Revisar calidad de los datos
Internet_Penetracion.isnull().sum() # Revisar si hay valores faltantes
Internet_Penetracion.dtypes # Verificar los tipos de datos de cada columna

# Resumen estadístico de la variable "Accesos por cada 100 hogares"
Internet_Penetracion["Accesos por cada 100 hogares"].describe() # Estadísticas descriptivas
Internet_Penetracion["Accesos por cada 100 hogares"].median() # Calcular la mediana

# Visualización de la distribución
sns.displot(data=Internet_Penetracion, x="Accesos por cada 100 hogares", kde=False, bins=20) # Histograma
sns.boxplot(data=Internet_Penetracion, x="Accesos por cada 100 hogares") # Diagrama de caja y bigotes
sns.kdeplot(data=Internet_Penetracion, x="Accesos por cada 100 hogares") # Diagrama de densidad

# Agrupación y análisis de tendencias
Internet_Penetracion.groupby("Provincia")["Accesos por cada 100 hogares"].mean() # Calcular el promedio por provincia
Internet_Penetracion.groupby(["Año", "Trimestre"])["Accesos por cada 100 hogares"].mean() # Calcular el promedio por trimestre

# Análisis exploratorio bivariado
sns.scatterplot(data=Internet_Penetracion, x="Año", y="Accesos por cada 100 hogares") # Scatter plot
sns.boxplot(data=Internet_Penetracion, x="Trimestre", y="Accesos por cada 100 hogares") # Box plot

# Detección de outliers
sns.boxplot(data=Internet_Penetracion, x="Accesos por cada 100 hogares") # Verificar si hay outliers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\nanops.py:760, in nanmedian(values, axis, skipna, mask)
#     759 try:
# --> 760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '78,11'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\oomph\Documents\Henry Data Science\DTS09_Proyecto_Individual02\Proyecto-TelecomArg\inicio.ipynb Cell 9 in 7
#       <a href='vscode-notebook-cell:/c%3A/Users/oomph/Documents/Henry%20Data%20Science/DTS09_Proyecto_Individual02/Proyecto-TelecomArg/inicio.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> # Resumen estadístico de la variable "Accesos por cada 100 hogares"
#       <a href='vscode-notebook-cell:/c%3A/Users/oomph/Documents/Henry%20Data%20Science/DTS09_Proyecto_Individual02/Proyecto-TelecomArg/inicio.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> Internet_Penetracion["Accesos por cada 100 hogares"].describe() # Estadísticas descriptivas
# ----> <a href='vscode-notebook-cell:/c%3A/Users/oomph/Documents/Henry%20Data%20Science/DTS09_Proyecto_Individual02/Proyecto-TelecomArg/inicio.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> Internet_Penetracion["Accesos por cada 100 hogares"].median() # Calcular la mediana
#       <a href='vscode-notebook-cell:/c%3A/Users/oomph/Documents/Henry%20Data%20Science/DTS09_Proyecto_Individual02/Proyecto-TelecomArg/inicio.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> # Visualización de la distribución
#      <a href='vscode-notebook-cell:/c%3A/Users/oomph/Documents/Henry%20Data%20Science/DTS09_Proyecto_Individual02/Proyecto-TelecomArg/inicio.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a> sns.displot(data=Internet_Penetracion, x="Accesos por cada 100 hogares", kde=False, bins=20) # Histograma
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:11917, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11899 @doc(
#   11900     _num_doc,
#   11901     desc="Return the median of the values over the requested axis.",
#    (...)
#   11915     **kwargs,
#   11916 ):
# > 11917     return NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:11413, in NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11405 def median(
#   11406     self,
#   11407     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11411     **kwargs,
#   11412 ) -> Series | float:
# > 11413     return self._stat_function(
#   11414         "median", nanops.nanmedian, axis, skipna, level, numeric_only, **kwargs
#   11415     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\nanops.py:763, in nanmedian(values, axis, skipna, mask)
#     760     values = values.astype("f8")
#     761 except ValueError as err:
#     762     # e.g. "could not convert string to float: 'a'"
# --> 763     raise TypeError(str(err)) from err
#     764 if mask is not None:
#     765     values[mask] = np.nan
#
# TypeError: could not convert string to float: '78,11'

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos desde el archivo CSV
Internet_TecyLocalidad = pd.read_csv("Proyecto-TelecomArg\\AccesosaInternetfijoportecnologiaylocalidad_2791751681941036387.csv", sep=";")

# Revisar calidad de los datos
Internet_TecyLocalidad.isnull().sum() # Revisar si hay valores faltantes
Internet_TecyLocalidad.dtypes # Verificar los tipos de datos de cada columna

# Eliminar la columna "Unnamed: 13"
Internet_TecyLocalidad = Internet_TecyLocalidad.drop(columns=["Unnamed: 13"])

# Resumen estadístico de las variables
Internet_TecyLocalidad.describe()

# Visualización de la distribución
sns.histplot(Internet_TecyLocalidad["ADSL"], kde=True, bins=10) # Histograma para la tecnología ADSL
sns.histplot(Internet_TecyLocalidad["CABLEMODEM"], kde=True, bins=10) # Histograma para la tecnología CABLEMODEM
sns.histplot(Internet_TecyLocalidad["DIAL UP"], kde=True, bins=10) # Histograma para la tecnología DIAL UP
sns.histplot(Internet_TecyLocalidad["FIBRA OPTICA"], kde=True, bins=10) # Histograma para la tecnología FIBRA OPTICA
sns.histplot(Internet_TecyLocalidad["OTROS"], kde=True, bins=10) # Histograma para la tecnología OTROS
sns.histplot(Internet_TecyLocalidad["SATELITAL"], kde=True, bins=10) # Histograma para la tecnología SATELITAL
sns.histplot(Internet_TecyLocalidad["WIMAX"], kde=True, bins=10) # Histograma para la tecnología WIMAX
sns.histplot(Internet_TecyLocalidad["WIRELESS"], kde=True, bins=10) # Histograma para la tecnología WIRELESS

# Agrupación y análisis de tendencias
tecnologias = ["ADSL", "CABLEMODEM", "DIAL UP", "FIBRA OPTICA", "OTROS", "SATELITAL", "WIMAX", "WIRELESS"]
Internet_TecyLocalidad.groupby("Provincia")[tecnologias].mean() # Calcular el promedio por provincia
Internet_TecyLocalidad.groupby("Partido")[tecnologias].mean() # Calcular el promedio por partido
Internet_TecyLocalidad.groupby("Localidad")[tecnologias].mean() # Calcular el promedio por localidad

# Análisis exploratorio bivariado
sns.scatterplot(data=Internet_TecyLocalidad, x="FIBRA OPTICA", y="CABLEMODEM", hue="Provincia") # Scatter plot para comparar FIBRA OPTICA y CABLEMODEM por provincia
sns.scatterplot(data=Internet_TecyLocalidad, x="WIMAX", y="WIRELESS", hue="Partido") # Scatter plot para comparar WIMAX y WIRELESS por partido

# Detección de outliers
sns.boxplot(data=Internet_TecyLocalidad[tecnologias]) # Verificar si hay outliers

# %%
# Revisar calidad de los datos
Velocidad_ProvTrimestral.isnull().sum() # Revisar si hay valores faltantes
Velocidad_ProvTrimestral.dtypes # Verificar los tipos de datos de cada columna

# Renombrar columnas
Velocidad_ProvTrimestral = Velocidad_ProvTrimestral.rename(columns={"Mbps (Media de bajada)": "Velocidad Media Bajada"})

# Resumen estadístico de la variable "Velocidad Media Bajada"
Velocidad_ProvTrimestral["Velocidad Media Bajada"].describe() # Estadísticas descriptivas

# Visualización de la distribución
sns.histplot(data=Velocidad_ProvTrimestral, x="Velocidad Media Bajada", bins=20) # Histograma
sns.boxplot(data=Velocidad_ProvTrimestral, x="Velocidad Media Bajada") # Diagrama de caja y bigotes

# Agrupación y análisis de tendencias
Velocidad_ProvTrimestral.groupby("Año")["Velocidad Media Bajada"].mean() # Calcular el promedio por año
Velocidad_ProvTrimestral.groupby("Trimestre")["Velocidad Media Bajada"].mean() # Calcular el promedio por trimestre
Velocidad_ProvTrimestral.groupby(["Año", "Trimestre"])["Velocidad Media Bajada"].agg(["mean", "median"]) # Calcular promedio y mediana por año y trimestre
Velocidad_ProvTrimestral.groupby("Trimestre.1")["Velocidad Media Bajada"].mean() # Calcular el promedio por trimestre.1

# Análisis exploratorio bivariado
sns.scatterplot(data=Velocidad_ProvTrimestral, x="Año", y="Velocidad Media Bajada", hue="Trimestre") # Scatter plot para comparar Velocidad Media Bajada y Año por Trimestre

# Detección de outliers
sns.boxplot(data=Velocidad_ProvTrimestral["Velocidad Media Bajada"]) # Verificar si hay outliers
